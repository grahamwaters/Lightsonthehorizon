# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import requests 
df = pd.read_csv('../data/ufo_clean.csv', low_memory=False)

# %%
url = 'http://srtm.csi.cgiar.org/SRT-ZIP/SRTM_float.zip?lat={}&lon={}'.format(39.7391536,-104.9847034)
# use requests to get the file
r = requests.get(url)
# save the file to disk
with open('SRTM_float.zip', 'wb') as f:
    f.write(r.content)

# show the elevation for the location
print(r.content)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File /opt/anaconda3/envs/groupme/lib/python3.9/site-packages/urllib3/contrib/pyopenssl.py:456, in PyOpenSSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455 try:
# --> 456     cnx.do_handshake()
#     457 except OpenSSL.SSL.WantReadError:
#
# File /opt/anaconda3/envs/groupme/lib/python3.9/site-packages/OpenSSL/SSL.py:1991, in Connection.do_handshake(self)
#    1990 result = _lib.SSL_do_handshake(self._ssl)
# -> 1991 self._raise_ssl_error(self._ssl, result)
#
# File /opt/anaconda3/envs/groupme/lib/python3.9/site-packages/OpenSSL/SSL.py:1700, in Connection._raise_ssl_error(self, ssl, result)
#    1699 else:
# -> 1700     _raise_current_error()
#
# ...
